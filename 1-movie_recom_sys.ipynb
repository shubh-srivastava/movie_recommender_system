# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\sriva\anaconda3\lib\site-packages (1.7.4.5)
# Requirement already satisfied: bleach in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (3.3.2)
# Requirement already satisfied: idna in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (3.7)
# Requirement already satisfied: protobuf in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (4.25.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (75.1.0)
# Requirement already satisfied: six>=1.10 in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: text-unidecode in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (4.66.5)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (2.2.3)
# Requirement already satisfied: webencodings in c:\users\sriva\anaconda3\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: packaging in c:\users\sriva\anaconda3\lib\site-packages (from bleach->kaggle) (24.1)
# Requirement already satisfied: colorama in c:\users\sriva\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)

# %%
import os
import shutil

# Make sure the .kaggle directory exists
os.makedirs(os.path.expanduser('~/.kaggle'), exist_ok=True)

# Move kaggle.json to the .kaggle directory
shutil.copy('kaggle.json', os.path.expanduser('~/.kaggle/kaggle.json'))

# Set proper permissions
os.chmod(os.path.expanduser('~/.kaggle/kaggle.json'), 0o600)

# %%
# !kaggle datasets download -d tmdb/tmdb-movie-metadata
# Out:
# Dataset URL: https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata
# License(s): other
# tmdb-movie-metadata.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

with zipfile.ZipFile("tmdb-movie-metadata.zip", "r") as zip_ref:
    zip_ref.extractall("movies_data")  # or any folder name

# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('movies_data/tmdb_5000_movies.csv')
credits = pd.read_csv('movies_data/tmdb_5000_credits.csv')

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
movies = movies.merge(credits,on='title')

# %%
movies.shape
# Out:
# (4809, 23)

# %% [markdown]
# selecting columns form all that will affect the results dropping all the rest

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.sample(5)
# Out:
#       movie_id                    title  \
# 1201       708     The Living Daylights
# 2541    134411                   Snitch
# 925      50646     Crazy, Stupid, Love.
# 1247     18937        Quest for Camelot
# 7        99861  Avengers: Age of Ultron
#
#                                                overview  \
# 1201  James Bond helps a Russian General escape into...
# 2541  Construction company owner John Matthews learn...
# 925   Cal Weaver is living the American dream. He ha...
# 1247  During the times of King Arthur, Kayley is a b...
# 7     When Tony Stark tries to jumpstart a dormant p...
#
#                                                  genres  \
# 1201  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 2541  [{"id": 53, "name": "Thriller"}, {"id": 18, "n...
# 925   [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 1247  [{"id": 14, "name": "Fantasy"}, {"id": 16, "na...
# 7     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                keywords  \
# 1201  [{"id": 212, "name": "london england"}, {"id":...
# 2541  [{"id": 494, "name": "father son relationship"...
# 925   [{"id": 815, "name": "soulmates"}, {"id": 1599...
# 1247                                                 []
# 7     [{"id": 8828, "name": "marvel comic"}, {"id": ...
#
#                                                    cast  \
# 1201  [{"cast_id": 18, "character": "James Bond", "c...
# 2541  [{"cast_id": 12, "character": "John Matthews",...
# 925   [{"cast_id": 3, "character": "Cal Weaver", "cr...
# 1247  [{"cast_id": 1, "character": "Kayley (voice)",...
# 7     [{"cast_id": 76, "character": "Tony Stark / Ir...
#
#                                                    crew
# 1201  [{"credit_id": "52fe426ec3a36847f801df5f", "de...
# 2541  [{"credit_id": "52fe4bd0c3a368484e19a431", "de...
# 925   [{"credit_id": "565b6197c3a368507d0034b0", "de...
# 1247  [{"credit_id": "59139064c3a36842c10005f4", "de...
# 7     [{"credit_id": "55d5f7d4c3a3683e7e0016eb", "de...

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
#dropping the movies with no overview
movies.dropna(inplace = True)

# %%
#checking for duplicates 
movies.duplicated().sum()
# Out:
# 0

# %% [markdown]
# making the array of strings to a list of keywords using ast

# %%
import ast

# %%
#making a function to get the genres of the movie 
def convert(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
movies['genres'] = movies['genres'].apply(convert)

# %%
#now applying the same thing to keywords
movies['keywords'] = movies['keywords'].apply(convert)

# %%
#making a function to get the genres of the movie 
def convert2(obj):
    L = []
    counter = 0
    for i in ast.literal_eval(obj):
        if counter != 3:
            L.append(i['name'])
            counter += 1
        else:
            break
    return L

# %%
movies['cast'] = movies['cast'].apply(convert2)

# %% [markdown]
# from the movies column we only need the director

# %%
def fetch_director(obj):
    L=[]
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            L.append(i['name'])
            break
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)

# %% [markdown]
# now from the overview column we will make a list

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %% [markdown]
# now we have all the column as list

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast                 crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      [James Cameron]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     [Gore Verbinski]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         [Sam Mendes]
# 3      [Christian Bale, Michael Caine, Gary Oldman]  [Christopher Nolan]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     [Andrew Stanton]

# %% [markdown]
# now we want to convert all the words in the columns so that they don't have any space so as to create only one tag for them

# %%
#making a function for it
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]

# %% [markdown]
# now we will combine all the columns into one column to make tags from it

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])
#new.head()

# %% [markdown]
# now we will convert the list in tags column into a string

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()

# %%
vector.shape
# Out:
# (4806, 5000)

# %% [markdown]
# we are calculating the difference of angles of vectors of different movies

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
#now we will make a function that will recommend movies to us

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
new.sample(20)
# Out:
#       movie_id                                              title  \
# 4560    322194                                       Subconscious
# 1825      6466                                   Freddy vs. Jason
# 2894     13079                           The Life Before Her Eyes
# 4232    127918                                    The Gatekeepers
# 104        503                                           Poseidon
# 1534    120467                           The Grand Budapest Hotel
# 2093       274                           The Silence of the Lambs
# 3759       512                                              Scoop
# 1184      6073                                        The Mexican
# 4389     39183  Once in a Lifetime: The Extraordinary Story of...
# 3602     26748                                          Lone Star
# 2045    204082                                          Homefront
# 1724     10577                                       Dracula 2000
# 1924     10655                                         Gettysburg
# 2256     13405                          The Children of Huang Shi
# 1521      3587                                              Bogus
# 707       9641                             Cheaper by the Dozen 2
# 719      13576                                         This Is It
# 2875     61752                                             Girl 6
# 2203     11382                              Bullets Over Broadway
#
#                                                    tags
# 4560  An investigation into a retired WWII sub plung...
# 1825  Evil dream-demon Freddy Krueger devises a plan...
# 2894  As the 15th anniversary of a fatal high school...
# 4232  In an unprecedented and candid series of inter...
# 104   A packed cruise ship traveling the Atlantic is...
# 1534  The Grand Budapest Hotel tells of a legendary ...
# 2093  FBI trainee, Clarice Starling ventures into a ...
# 3759  An American journalism student in London scoop...
# 1184  Jerry Welbach, a reluctant bagman, has been gi...
# 4389  In the 1970s the North American Soccer League ...
# 3602  When the skeleton of his murdered predecessor ...
# 2045  Phil Broker is a former DEA agent who has gone...
# 1724  In the millenium version of this classic Gothi...
# 1924  Summer 1863. The Confederacy pushes north into...
# 2256  About young British journalist, George Hogg, w...
# 1521  Recently orphaned, a young boy is taken in by ...
# 707   Steve Martin and Bonnie Hunt return as heads o...
# 719   A compilation of interviews, rehearsals and ba...
# 2875  Girl 6 is a 1996 American film by director Spi...
# 2203  Set in 1920's New York City, this movie tells ...

# %%
recommend('Bogus')
# Out:
# The Boxtrolls
# Nicholas Nickleby
# Shipwrecked
# Duma
# Growing Up Smith

# %%
import pickle

# %%
pickle.dump(new.to_dict(),open('movie_dict.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))
